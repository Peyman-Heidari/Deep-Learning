# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
    save = pickle.load(f, encoding='latin1')
    train_dataset = save['train_dataset']
    train_labels = save['train_labels']
    valid_dataset = save['valid_dataset']
    valid_labels = save['valid_labels']
    test_dataset = save['test_dataset']
    test_labels = save['test_labels']
    del save  # hint to help gc free up memory
    print('Training set', train_dataset.shape, train_labels.shape)
    print('Validation set', valid_dataset.shape, valid_labels.shape)
    print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
    dataset = dataset.reshape((-1, image_size, image_size, num_channels)).astype(np.float32)
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))/ predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    
    layer3_weights = tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph, config=tf.ConfigProto(log_device_placement=True)) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.649235
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.1%
# Minibatch loss at step 50: 1.733198
# Minibatch accuracy: 25.0%
# Validation accuracy: 55.0%
# Minibatch loss at step 100: 1.039068
# Minibatch accuracy: 62.5%
# Validation accuracy: 66.0%
# Minibatch loss at step 150: 0.492903
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.8%
# Minibatch loss at step 200: 0.808220
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.3%
# Minibatch loss at step 250: 1.214091
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.1%
# Minibatch loss at step 300: 0.340941
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 350: 0.565066
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.9%
# Minibatch loss at step 400: 0.220606
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.6%
# Minibatch loss at step 450: 0.911739
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.0%
# Minibatch loss at step 500: 0.724327
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 550: 1.197607
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.6%
# Minibatch loss at step 600: 0.258600
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 650: 0.763128
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 700: 0.876179
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 750: 0.076656
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 800: 0.698365
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 850: 1.095954
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 900: 0.566004
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 950: 0.518593
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.4%
# Minibatch loss at step 1000: 0.431049
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.9%
# Test accuracy: 89.4%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    
    layer3_weights = tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    #layer3_weights = tf.Variable(tf.truncated_normal([image_size * image_size * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        conv = tf.nn.max_pool(conv, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        conv = tf.nn.max_pool(conv, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 5.152431
# Minibatch accuracy: 6.2%
# Validation accuracy: 9.6%
# Minibatch loss at step 50: 2.048174
# Minibatch accuracy: 31.2%
# Validation accuracy: 39.1%
# Minibatch loss at step 100: 1.065317
# Minibatch accuracy: 62.5%
# Validation accuracy: 54.3%
# Minibatch loss at step 150: 0.527542
# Minibatch accuracy: 87.5%
# Validation accuracy: 72.7%
# Minibatch loss at step 200: 1.034594
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.9%
# Minibatch loss at step 250: 1.261616
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.6%
# Minibatch loss at step 300: 0.443226
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 350: 0.624064
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 400: 0.279447
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.4%
# Minibatch loss at step 450: 0.847892
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 500: 0.579803
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 550: 0.688717
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 600: 0.288422
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.5%
# Minibatch loss at step 650: 0.941240
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 700: 0.836427
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 750: 0.067562
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 800: 0.647114
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# Minibatch loss at step 850: 0.847863
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 900: 0.624033
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 950: 0.405030
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 1000: 0.393917
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Test accuracy: 90.3%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 128

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))

    layer3_weights = tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    #layer3_weights = tf.Variable(tf.truncated_normal([image_size * image_size * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    layer33_weights = tf.Variable(tf.truncated_normal([num_hidden, num_hidden], stddev=0.1))
    #layer3_weights = tf.Variable(tf.truncated_normal([image_size * image_size * depth, num_hidden], stddev=0.1))
    layer33_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    layer34_weights = tf.Variable(tf.truncated_normal([num_hidden, num_hidden], stddev=0.1))
    #layer3_weights = tf.Variable(tf.truncated_normal([image_size * image_size * depth, num_hidden], stddev=0.1))
    layer34_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
    
    global_step = tf.Variable(0)
  
    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        conv = tf.nn.max_pool(conv, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        conv = tf.nn.max_pool(conv, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        
        
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        hidden = tf.nn.relu(tf.matmul(hidden, layer33_weights) + layer33_biases)
        hidden = tf.nn.relu(tf.matmul(hidden, layer34_weights) + layer34_biases)
        return hidden
  
    # Training computation.
    hidden = model(tf_train_dataset)
    layer4_weights_drop = tf.nn.dropout(layer4_weights, 0.5)
    logits = tf.matmul(hidden, layer4_weights_drop) + layer4_biases
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
    # Optimizer.
    learning_rate = tf.train.exponential_decay(0.05, global_step, 100000, 0.96)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_hidden = model(tf_valid_dataset)
    valid_logits = logits = tf.matmul(valid_hidden, layer4_weights) + layer4_biases
    valid_prediction = tf.nn.softmax(valid_logits)
    
    test_hidden = model(tf_test_dataset)
    test_logits = logits = tf.matmul(test_hidden, layer4_weights) + layer4_biases
    test_prediction = tf.nn.softmax(test_logits)

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.093224
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.983935
# Minibatch accuracy: 18.8%
# Validation accuracy: 39.7%
# Minibatch loss at step 100: 1.623377
# Minibatch accuracy: 37.5%
# Validation accuracy: 52.9%
# Minibatch loss at step 150: 1.077866
# Minibatch accuracy: 62.5%
# Validation accuracy: 64.9%
# Minibatch loss at step 200: 1.460415
# Minibatch accuracy: 37.5%
# Validation accuracy: 74.3%
# Minibatch loss at step 250: 1.316367
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.4%
# Minibatch loss at step 300: 0.634898
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.6%
# Minibatch loss at step 350: 0.666971
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.4%
# Minibatch loss at step 400: 0.589644
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.2%
# Minibatch loss at step 450: 0.680733
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.3%
# Minibatch loss at step 500: 0.874097
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 550: 1.036994
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.2%
# Minibatch loss at step 600: 0.285748
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.5%
# Minibatch loss at step 650: 0.710840
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.2%
# Minibatch loss at step 700: 0.842498
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 750: 0.193281
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 800: 0.547411
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 850: 1.026965
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 900: 0.619287
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 950: 0.613418
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss at step 1000: 0.383412
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.3%
# Minibatch loss at step 1050: 0.554111
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 1100: 0.713335
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 1150: 0.346885
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 1200: 1.049902
# Minibatch accuracy: 62.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 1250: 0.618743
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 1300: 0.493123
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 1350: 0.752834
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 1400: 0.211348
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 1450: 0.253095
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 1500: 0.706038
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.6%
# Minibatch loss at step 1550: 0.576988
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# Minibatch loss at step 1600: 1.225979
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 1650: 0.595878
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 1700: 0.465753
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 1750: 0.481200
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.5%
# Minibatch loss at step 1800: 0.538692
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 1850: 0.905995
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 1900: 0.345945
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 1950: 0.549726
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.7%
# Minibatch loss at step 2000: 0.133922
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 2050: 0.767759
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 2100: 0.325306
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 2150: 0.450264
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 2200: 0.396285
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 2250: 0.459678
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 2300: 0.490272
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 2350: 0.507269
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 2400: 0.570942
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.6%
# Minibatch loss at step 2450: 0.471431
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 2500: 0.731116
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.7%
# Minibatch loss at step 2550: 0.394909
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 2600: 0.037909
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 2650: 0.180776
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 2700: 0.270857
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 2750: 0.822043
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 2800: 0.472957
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 2850: 0.151264
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 2900: 0.449882
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 2950: 0.352879
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 3000: 0.665631
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 3050: 0.280515
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 3100: 0.426843
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 3150: 1.004788
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 3200: 0.356398
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.6%
# Minibatch loss at step 3250: 0.401051
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 3300: 0.157770
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 3350: 0.187395
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 3400: 0.280001
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 3450: 0.308794
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 3500: 0.535910
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 3550: 0.176298
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 3600: 0.109376
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 3650: 0.647059
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 3700: 1.089265
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 3750: 1.007426
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 3800: 0.009585
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.2%
# Minibatch loss at step 3850: 0.486895
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 3900: 0.609522
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.6%
# Minibatch loss at step 3950: 0.002157
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 4000: 0.445386
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.6%
# Minibatch loss at step 4050: 0.764780
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 4100: 0.325573
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 4150: 1.040821
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 4200: 0.231722
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 4250: 0.393180
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step