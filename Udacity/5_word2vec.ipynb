# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5242, 3082, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.810605
# Nearest to its: menthol, rerum, sex, mural, obviously, treating, consequences, heeled,
# Nearest to all: liking, saturn, slaying, carpetbaggers, overboard, wishes, clockwise, consistent,
# Nearest to which: traveller, laver, ultima, humanists, bluebeard, plans, refinements, lombardo,
# Nearest to time: alberto, reaction, complaint, niggers, ks, hydrosphere, doomed, patrols,
# Nearest to s: keynesian, cooke, mascot, susima, depleting, gandhara, superimposed, handler,
# Nearest to are: domitius, magdalene, resistive, duplication, impede, tempo, shakespearean, tender,
# Nearest to will: reed, activated, pattie, circumcising, porridge, scorpio, ctor, coping,
# Nearest to or: turnover, kurt, modalities, galaxies, potters, homophones, wildstorm, qassam,
# Nearest to into: unbelievable, kicker, commence, elaborating, suicides, redistricting, casuistry, yauch,
# Nearest to this: luddites, exaggerating, doubtful, praetorians, habib, centimetres, playwright, fft,
# Nearest to called: mesa, technician, whistler, hypnotic, entailed, laborer, plot, technologically,
# Nearest to more: alger, laramie, townsfolk, admirable, lust, valentin, pett, primal,
# Nearest to after: pelvis, accademia, speedway, honoring, emblematic, iris, corbett, expressions,
# Nearest to between: diels, ration, rushton, depicting, loma, sada, communal, translational,
# Nearest to by: trades, aoun, bachchan, homologous, claimants, registrations, itch, displacements,
# Nearest to be: hipc, river, principle, compelled, rains, kamenev, guerrillas, horde,
# Average loss at step 2000: 4.356866
# Average loss at step 4000: 3.859191
# Average loss at step 6000: 3.784252
# Average loss at step 8000: 3.687250
# Average loss at step 10000: 3.609881
# Nearest to its: his, the, treating, their, heapsort, sex, hurdles, hilaire,
# Nearest to all: grumpy, audi, carpetbaggers, carrot, liking, wishes, each, carradine,
# Nearest to which: this, also, it, who, what, that, ishiro, lombardo,
# Nearest to time: patrols, apostasy, shehri, galatians, actuarial, alberto, confederation, accounts,
# Nearest to s: his, polycarbonate, and, perennially, imperfect, renderings, overrides, dimensionless,
# Nearest to are: were, is, have, estonian, duddy, cheat, intersex, was,
# Nearest to will: would, could, laminar, scorpio, ctor, reed, might, contacts,
# Nearest to or: and, tarsus, than, digest, arithmetica, slideshow, delivering, disestablishment,
# Nearest to into: from, commence, elaborating, yauch, experimental, nba, kicker, adage,
# Nearest to this: it, which, the, a, vesa, browski, what, that,
# Nearest to called: technician, mesa, plot, technologically, bra, qatar, signifier, joint,
# Nearest to more: alger, rothschild, staircase, tool, lug, uruk, townsfolk, pett,
# Nearest to after: mbox, ifs, confined, xa, speedway, xyz, in, moqed,
# Nearest to between: with, diels, ration, in, kwanzaa, among, nebulous, rushton,
# Nearest to by: was, be, as, been, with, aoun, designates, emigre,
# Nearest to be: have, by, was, dusseldorf, hipc, is, steered, strategies,
# Average loss at step 12000: 3.603953
# Average loss at step 14000: 3.570444
# Average loss at step 16000: 3.407880
# Average loss at step 18000: 3.455424
# Average loss at step 20000: 3.538832
# Nearest to its: their, the, his, treating, her, cilicia, hurdles, heapsort,
# Nearest to all: many, some, carpetbaggers, both, grumpy, worthington, carradine, those,
# Nearest to which: this, that, who, it, but, also, there, what,
# Nearest to time: apostasy, year, patrols, confederation, accounts, years, brute, period,
# Nearest to s: emc, weasel, cab, persecuting, interviews, radio, weep, polycarbonate,
# Nearest to are: were, is, have, was, tritone, cheat, duddy, estonian,
# Nearest to will: would, could, can, might, may, must, should, laminar,
# Nearest to or: and, than, arithmetica, for, machinist, tarsus, eth, incentive,
# Nearest to into: from, commence, suleiman, nba, elaborating, appian, bug, adage,
# Nearest to this: it, which, what, the, another, he, middlesbrough, that,
# Nearest to called: signifier, technician, norad, used, consequentialism, mesa, hypnotic, known,
# Nearest to more: less, most, tool, rothschild, alger, impure, lug, succumbed,
# Nearest to after: before, ifs, mbox, xa, when, deansgate, mamre, xyz,
# Nearest to between: with, diels, kwanzaa, in, among, from, matlab, rushton,
# Nearest to by: be, in, designates, for, aoun, lexicographic, domes, being,
# Nearest to be: have, been, by, is, was, assigns, cherished, refer,
# Average loss at step 22000: 3.503591
# Average loss at step 24000: 3.483557
# Average loss at step 26000: 3.480696
# Average loss at step 28000: 3.475861
# Average loss at step 30000: 3.500984
# Nearest to its: their, his, the, her, your, hurdles, our, practised,
# Nearest to all: some, many, those, these, various, both, any, were,
# Nearest to which: this, that, but, it, who, what, also, austin,
# Nearest to time: year, apostasy, period, brute, rowers, accounts, lanes, confederation,
# Nearest to s: his, mockingbird, bas, alf, isbn, norwich, lays, tarsus,
# Nearest to are: were, have, tritone, is, other, these, cheat, include,
# Nearest to will: would, could, can, might, may, must, laminar, should,
# Nearest to or: and, tarsus, arithmetica, than, nasser, sussex, nemo, banana,
# Nearest to into: from, commence, appian, nba, ingots, suleiman, through, and,
# Nearest to this: it, which, what, another, that, toolkit, barefoot, adhere,
# Nearest to called: used, norad, technician, considered, known, luncheon, technologically, hypnotic,
# Nearest to more: less, most, rothschild, staircase, alger, impure, very, abort,
# Nearest to after: before, during, when, ifs, mbox, from, xa, prolonged,
# Nearest to between: with, kwanzaa, among, diels, in, kuznetsov, aug, matlab,
# Nearest to by: under, bjelke, as, in, designates, euskadi, spacesuit, demarcation,
# Nearest to be: been, have, refer, is, are, become, dusseldorf, were,
# Average loss at step 32000: 3.498817
# Average loss at step 34000: 3.497424
# Average loss at step 36000: 3.450108
# Average loss at step 38000: 3.303043
# Average loss at step 40000: 3.427335
# Nearest to its: their, his, her, the, your, our, hybridized, hurdles,
# Nearest to all: both, many, carrot, some, several, postdoctoral, various, those,
# Nearest to which: that, this, who, also, it, there, what, often,
# Nearest to time: year, apostasy, way, received, years, period, gama, inline,
# Nearest to s: his, mockingbird, atonal, lays, isbn, chia, lak, birding,
# Nearest to are: were, is, have, duddy, be, these, those, including,
# Nearest to will: would, can, could, may, must, might, should, laminar,
# Nearest to or: and, than, to, nasser, hyperinsulinism, syllabic, salaries, subsidiaries,
# Nearest to into: from, through, appian, suleiman, sole, elaborating, nba, solid,
# Nearest to this: which, it, another, that, the, what, markov, steiner,
# Nearest to called: used, considered, norad, known, bookshelf, see, technologically, luncheon,
# Nearest to more: less, most, very, highly, staircase, larger, nitz, uruk,
# Nearest to after: before, when, during, mbox, elapsed, ifs, thousand, xa,
# Nearest to between: with, among, diels, lc, across, until, kwanzaa, in,
# Nearest to by: designates, be, domes, being, for, as, with, taif,
# Nearest to be: have, been, refer, is, are, by, assigns, being,
# Average loss at step 42000: 3.436609
# Average loss at step 44000: 3.451526
# Average loss at step 46000: 3.451592
# Average loss at step 48000: 3.349295
# Average loss at step 50000: 3.386153
# Nearest to its: their, his, the, her, your, our, whose, prescott,
# Nearest to all: both, many, syntactical, some, agrippina, those, various, rows,
# Nearest to which: this, that, who, also, what, these, avestan, but,
# Nearest to time: year, way, day, period, debate, apostasy, gama, recovered,
# Nearest to s: isbn, whose, kantian, his, lays, mockingbird, foster, monica,
# Nearest to are: were, is, have, those, these, estonian, be, was,
# Nearest to will: would, can, could, may, must, might, should, cannot,
# Nearest to or: and, than, arithmetica, dictation, swordfish, extracted, guyanese, nasser,
# Nearest to into: from, through, suleiman, solid, appian, ingots, within, commence,
# Nearest to this: which, it, another, the, tlatoani, he, some, crescas,
# Nearest to called: used, known, uncomfortable, considered, norad, lemnos, kilometre, signifier,
# Nearest to more: less, most, very, highly, faster, nitz, quite, larger,
# Nearest to after: before, when, during, ifs, but, elapsed, while, since,
# Nearest to between: with, among, in, diels, kwanzaa, hornblower, across, exemptions,
# Nearest to by: under, with, through, in, was, euskadi, designates, exacting,
# Nearest to be: been, have, refer, become, were, bolstered, was, being,
# Average loss at step 52000: 3.436137
# Average loss at step 54000: 3.428692
# Average loss at step 56000: 3.436164
# Average loss at step 58000: 3.394814
# Average loss at step 60000: 3.386608
# Nearest to its: their, his, the, her, your, our, evaporating, flensburg,
# Nearest to all: many, both, those, agrippina, some, any, these, morphology,
# Nearest to which: that, this, what, these, who, it, however, but,
# Nearest to time: debate, year, way, day, lanes, apostasy, period, kind,
# Nearest to s: whose, lays, although, reuter, mockingbird, chia, chaired, crank,
# Nearest to are: were, is, have, these, include, including, tritone, preterist,
# Nearest to will: would, could, can, may, must, might, should, cannot,
# Nearest to or: and, than, vfa, nasser, machinist, bosco, racks, for,
# Nearest to into: through, from, ingots, within, sensing, commence, under, suleiman,
# Nearest to this: which, it, that, there, another, itself, some, the,
# Nearest to called: used, considered, known, uncomfortable, named, referred, ghiorso, prevailing,
# Nearest to more: less, very, most, larger, rather, highly, faster, nitz,
# Nearest to after: before, during, when, ifs, without, while, although, opcw,
# Nearest to between: among, with, kwanzaa, diels, lc, over, aug, against,
# Nearest to by: through, under, without, patenting, euskadi, be, with, from,
# Nearest to be: been, was, is, refer, become, have, bolstered, by,
# Average loss at step 62000: 3.241173
# Average loss at step 64000: 3.257091
# Average loss at step 66000: 3.404538
# Average loss at step 68000: 3.397745
# Average loss at step 70000: 3.359789
# Nearest to its: their, the, his, your, her, our, whose, flensburg,
# Nearest to all: some, many, agrippina, any, both, those, various, haddo,
# Nearest to which: that, this, what, also, but, actually, who, usually,
# Nearest to time: way, debate, recovered, belief, lanes, round, place, expatriates,
# Nearest to s: mockingbird, whose, lays, wallpaper, kantian, sparrows, papert, or,
# Nearest to are: were, have, is, include, including, be, although, flynn,
# Nearest to will: would, could, may, can, must, might, should, cannot,
# Nearest to or: and, while, swordfish, than, nasser, the, darnley, any,
# Nearest to into: from, through, suleiman, ingots, within, around, commence, keywords,
# Nearest to this: it, which, another, that, there, the, what, authorized,
# Nearest to called: considered, named, used, known, referred, prevailing, uncomfortable, improper,
# Nearest to more: less, most, very, faster, larger, highly, rather, quite,
# Nearest to after: before, during, when, while, without, leaderships, ifs, if,
# Nearest to between: among, with, diels, utraquists, lc, aug, kwanzaa, hypertext,
# Nearest to by: using, through, without, be, euskadi, designates, in, taif,
# Nearest to be: been, is, become, were, have, being, are, by,
# Average loss at step 72000: 3.371079
# Average loss at step 74000: 3.349404
# Average loss at step 76000: 3.314629
# Average loss at step 78000: 3.347280
# Average loss at step 80000: 3.382457
# Nearest to its: their, his, your, her, the, whose, our, schweitzer,
# Nearest to all: both, any, every, many, various, each, several, syntactical,
# Nearest to which: that, this, usually, also, what, however, actually, who,
# Nearest to time: round, year, galatians, interacting, sudanese, lanes, debate, place,
# Nearest to s: mockingbird, isbn, medians, tilted, felix, anguish, his, imperfect,
# Nearest to are: were, include, have, is, although, including, these, flynn,
# Nearest to will: would, could, can, may, must, might, should, cannot,
# Nearest to or: and, than, while, syndromes, nasser, salaam, but, jessie,
# Nearest to into: through, from, suleiman, within, around, ingots, nagasaki, dalits,
# Nearest to this: which, it, another, the, what, there, that, authorized,
# Nearest to called: considered, known, named, referred, used, prevailing, uncomfortable, mico,
# Nearest to more: less, very, most, larger, faster, rather, quite, highly,
# Nearest to after: before, during, when, while, without, ifs, from, if,
# Nearest to between: among, with, diels, within, utraquists, over, kwanzaa, lc,
# Nearest to by: through, using, under, designates, taif, from, euskadi, and,
# Nearest to be: been, have, become, being, were, easily, refer, bolstered,
# Average loss at step 82000: 3.406374
# Average loss at step 84000: 3.408404
# Average loss at step 86000: 3.392961
# Average loss at step 88000: 3.355074
# Average loss at step 90000: 3.362101
# Nearest to its: their, his, her, your, the, whose, our, trianon,
# Nearest to all: many, several, both, some, every, syntactical, any, each,
# Nearest to which: that, this, also, what, who, usually, these, often,
# Nearest to time: year, round, experience, recovered, bacilli, finale, cossack, way,
# Nearest to s: whose, his, isbn, lays, echoed, prolong, rugova, reuter,
# Nearest to are: were, these, is, include, have, flynn, can, those,
# Nearest to will: would, could, can, may, must, might, should, cannot,
# Nearest to or: and, while, syndromes, dismayed, nasser, avram, than, cougars,
# Nearest to into: from, through, ingots, suleiman, around, nagasaki, back, inside,
# Nearest to this: it, which, another, some, itself, markov, the, tlatoani,
# Nearest to called: considered, referred, used, named, known, prevailing, asparagales, uncomfortable,
# Nearest to more: less, very, most, faster, highly, quite, rather, larger,
# Nearest to after: before, during, when, while, without, if, until, elapsed,
# Nearest to between: with, among, within, against, in, diels, aug, hypertext,
# Nearest to by: without, using, with, through, circumnavigation, designates, under, from,
# Nearest to be: been, was, have, become, being, respond, is, refer,
# Average loss at step 92000: 3.396008
# Average loss at step 94000: 3.252891
# Average loss at step 96000: 3.357050
# Average loss at step 98000: 3.235460
# Average loss at step 100000: 3.357284
# Nearest to its: their, his, her, the, your, whose, our, widest,
# Nearest to all: many, these, every, several, both, some, syntactical, any,
# Nearest to which: that, this, what, usually, these, who, actually, also,
# Nearest to time: round, year, way, interacting, recovered, winter, shrinking, kind,
# Nearest to s: whose, his, isbn, my, our, monica, chia, her,
# Nearest to are: were, have, include, these, although, while, those, flynn,
# Nearest to will: would, could, can, must, should, may, might, cannot,
# Nearest to or: and, than, bosco, masterwork, syndromes, loyalist, hyperinsulinism, nasser,
# Nearest to into: through, from, within, suleiman, upon, with, across, in,
# Nearest to this: which, it, another, itself, there, some, he, markov,
# Nearest to called: named, referred, considered, used, known, termed, uncomfortable, and,
# Nearest to more: less, very, most, larger, faster, quite, highly, rather,
# Nearest to after: before, when, during, without, while, if, although, until,
# Nearest to between: among, with, against, within, diels, aug, into, ridges,
# Nearest to by: without, through, using, euskadi, when, been, vasa, from,
# Nearest to be: been, have, become, refer, is, respond, blondie, easily,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_CBOW(batch_size, investigation_window):
    global data_index
    span = 2 * investigation_window + 1 # [ skip_window target skip_window ]
    batch = np.ndarray(shape=(batch_size, span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size ):
        buffer_copy = buffer.copy()
        labels[i , 0] = buffer_copy[investigation_window]
        del buffer_copy[investigation_window]
        batch[i] = buffer_copy
        buffer.remove(buffer[0])
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels


print('data:', [reverse_dictionary[di] for di in data[:10]])

for investigation_window in [1,4]:
    data_index = 0
    batch, labels = generate_batch_CBOW(batch_size=3, investigation_window=investigation_window)
    print('\nwith investigation_window = %d ' % investigation_window)
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(3)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with investigation_window = 1
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term']]
#     labels: ['originated', 'as', 'a']
#
# with investigation_window = 4
#     batch: [['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used'], ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against'], ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early']]
#     labels: ['term', 'of', 'abuse']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
investigation_window = 3 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, investigation_window*2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    bow_embedding = tf.reduce_sum(embed, 1)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, bow_embedding,
                               train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch_CBOW(batch_size, investigation_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.685844
# Nearest to b: wh, vpn, volition, unaccustomed, grant, catchphrase, bremerhaven, charcoal,
# Nearest to not: euro, crackers, myspace, sands, philanthropic, plank, photoelectric, adage,
# Nearest to may: mothersbaugh, strikers, vigour, yankovic, chaste, commodities, minarchists, loeb,
# Nearest to was: trioxide, nebraska, injured, czechs, pleasurable, erudite, nihonshoki, washing,
# Nearest to american: kangaroo, php, historiographical, implant, missouri, mediums, prevailed, recycle,
# Nearest to of: warships, origen, bremerhaven, oicw, ruthlessness, distinguishing, gloves, koine,
# Nearest to so: wildcat, stupa, krieger, relena, microprogram, yugoslavian, teaser, archaea,
# Nearest to but: clampett, interchanged, octavius, directed, mordor, dwelt, sibelius, dominant,
# Nearest to which: muralitharan, aide, inlet, upheavals, inwardly, spikes, strategists, dunne,
# Nearest to all: busts, brush, rob, aalto, respiratory, ict, supplied, moto,
# Nearest to five: incessantly, acura, bel, inadequate, draugr, elas, frisians, yyyy,
# Nearest to seven: perens, fielding, indefatigable, calamities, kgf, commons, secrecy, fondness,
# Nearest to on: sorted, surrogate, lob, infusions, outcomes, vit, diarrhea, trolls,
# Nearest to and: genetically, interacting, rosenzweig, redefinition, fundamentals, capacity, recognized, smooth,
# Nearest to the: dolce, stimulus, loathing, mik, ipf, bataan, personae, split,
# Nearest to if: sina, additions, posits, devote, notate, excuse, clos, shipping,
# Average loss at step 2000: 5.340932
# Average loss at step 4000: 4.581136
# Average loss at step 6000: 11.825796
# Average loss at step 8000: 6.283829
# Average loss at step 10000: 4.735806
# Nearest to b: legge, lindsay, khorasan, dm, nagasaki, electrophoresis, statehood, crematoria,
# Nearest to not: cute, shih, formulas, longford, theravada, yogi, patricio, it,
# Nearest to may: can, would, must, will, could, should, might, to,
# Nearest to was: is, became, were, are, had, disadvantageous, could, injector,
# Nearest to american: origination, crass, sint, nano, stamford, america, package, phocas,
# Nearest to of: kwanza, joint, in, scythians, guilford, incompletely, parameters, leroy,
# Nearest to so: curled, mulberry, rence, resident, hashish, fly, indexing, advancing,
# Nearest to but: livery, commotion, third, isolating, lith, marple, see, drawing,
# Nearest to which: that, who, queueing, it, this, ruinous, abraxas, salah,
# Nearest to all: intracranial, merging, freire, persistently, bethe, gasp, weaning, vista,
# Nearest to five: ideologue, two, ostrava, injections, atrial, dalnet, basilisk, karl,
# Nearest to seven: northumbria, comstock, len, six, designations, stemming, mechanic, commuted,
# Nearest to on: in, bentine, under, wace, thirds, weren, from, alligators,
# Nearest to and: haight, muses, seasonal, puma, badge, adolescent, starling, scrolling,
# Nearest to the: a, his, any, an, this, another, assertions, its,
# Nearest to if: eldorado, dhea, when, lukewarm, that, retina, conjectured, rankings,
# Average loss at step 12000: 4.291433
# Average loss at step 14000: 3.778244
# Average loss at step 16000: 3.973727
# Average loss at step 18000: 3.874785
# Average loss at step 20000: 4.000123
# Nearest to b: d, delos, watered, vpn, compensating, jstor, establishing, lading,
# Nearest to not: devotion, converted, satisfies, retaliate, ergodic, temporarily, battled, thujone,
# Nearest to may: would, should, might, can, must, could, will, cannot,
# Nearest to was: is, were, became, are, being, did, remains, had,
# Nearest to american: british, phraseology, russian, drier, dials, incorrectly, english, sometimes,
# Nearest to of: in, following, main, sephardi, within, aceh, catal, coconuts,
# Nearest to so: disparity, estranged, scotland, boomerangs, abuses, fixation, mapsto, miyamoto,
# Nearest to but: undamaged, cayce, housemates, dutchman, mississippian, dumping, employee, randomness,
# Nearest to which: that, what, typically, also, generally, these, olds, who,
# Nearest to all: several, shocked, filmfour, many, dawning, dinner, upholds, memorably,
# Nearest to five: four, seven, eight, zero, three, pir, beavers, two,
# Nearest to seven: eight, five, six, nine, four, three, ambivalence, obscurity,
# Nearest to on: upon, accessibility, within, representing, jamaican, boisbaudran, in, tokelau,
# Nearest to and: than, agave, exhortations, feelgood, lacanian, lovely, wyche, flutes,
# Nearest to the: its, a, an, this, their, any, startled, galatian,
# Nearest to if: where, when, robb, fiesole, though, storyteller, licence, telecoms,
# Average loss at step 22000: 3.860720
# Average loss at step 24000: 4.036811
# Average loss at step 26000: 3.865392
# Average loss at step 28000: 3.803609
# Average loss at step 30000: 3.618957
# Nearest to b: mordechai, revolutions, yung, languished, jstor, d, metabolites, thing,
# Nearest to not: it, still, tramlink, never, temporarily, there, lymphatic, resentful,
# Nearest to may: should, would, could, can, must, cannot, will, might,
# Nearest to was: is, were, became, are, remains, had, remained, being,
# Nearest to american: adventurer, british, vacationing, tissot, dream, typesetting, australian, watercolor,
# Nearest to of: cite, incompletely, malmesbury, ibsen, in, airfields, like, toro,
# Nearest to so: very, quantum, bose, obedience, exclusion, punctured, later, atomic,
# Nearest to but: although, yet, hemispheric, until, piccolo, than, undamaged, eschenbach,
# Nearest to which: that, these, this, typically, usually, also, what, elmira,
# Nearest to all: many, several, autopsy, various, their, every, willfully, some,
# Nearest to five: eight, three, nine, four, six, seven, pertain, zero,
# Nearest to seven: eight, six, nine, five, idiomatic, adom, ssn, mull,
# Nearest to on: upon, in, within, magnetite, nami, joins, gatekeeper, accessibility,
# Nearest to and: including, like, dartmouth, while, endorse, husky, tricolor, rilke,
# Nearest to the: a, its, another, this, any, his, softer, an,
# Nearest to if: where, when, like, though, loader, chance, vehicular, odds,
# Average loss at step 32000: 3.578448
# Average loss at step 34000: 3.583004
# Average loss at step 36000: 3.606418
# Average loss at step 38000: 3.572007
# Average loss at step 40000: 3.534978
# Nearest to b: stoic, clergymen, roadie, lien, gangsta, scientist, egoism, landesverband,
# Nearest to not: never, so, thujone, worthwhile, canceling, headache, still, bigcup,
# Nearest to may: should, can, could, must, would, will, might, cannot,
# Nearest to was: is, were, became, are, had, becomes, has, gives,
# Nearest to american: canadian, xenosaga, german, british, references, ngos, insulator, cameras,
# Nearest to of: among, in, throughout, sephardi, totalled, cris, cambridgeshire, ibsen,
# Nearest to so: fins, not, too, kilns, satisfies, carpenters, grim, slam,
# Nearest to but: although, and, though, while, however, compatriots, replenishment, biddle,
# Nearest to which: who, that, this, wand, when, whose, minden, where,
# Nearest to all: some, many, dinner, various, other, thousands, certain, strengthens,
# Nearest to five: seven, six, four, zero, motorsports, valiente, mahoney, three,
# Nearest to seven: six, four, five, nine, eight, miquelon, cois, three,
# Nearest to on: upon, through, since, sylvester, aceh, sorted, cornet, beyond,
# Nearest to and: or, but, while, when, than, reactant, coconuts, supplementation,
# Nearest to the: a, this, his, its, an, their, militants, grin,
# Nearest to if: when, where, though, since, although, because, nor, indomitable,
# Average loss at step 42000: 3.543925
# Average loss at step 44000: 3.376072
# Average loss at step 46000: 3.484014
# Average loss at step 48000: 3.489347
# Average loss at step 50000: 3.432185
# Nearest to b: project, hau, anemometer, model, condoleezza, democratique, nonzero, expands,
# Nearest to not: never, still, so, nothing, polyalphabetic, canceling, greenspan, almost,
# Nearest to may: must, should, could, can, would, might, will, cannot,
# Nearest to was: is, were, became, are, becomes, had, makes, remains,
# Nearest to american: america, russian, australian, insulator, komodo, riddled, escorted, lathes,
# Nearest to of: in, following, during, throughout, among, aceh, sephardi, across,
# Nearest to so: say, recognize, fins, too, not, pedals, formalize, countable,
# Nearest to but: though, although, until, however, than, yet, that, which,
# Nearest to which: that, this, whose, who, indignant, sacs, recapitulation, what,
# Nearest to all: several, these, some, other, many, kitt, both, heeded,
# Nearest to five: four, three, zero, comforts, pva, dao, evocative, selassie,
# Nearest to seven: eight, lintel, four, atherosclerosis, tulip, cartographic, project, model,
# Nearest to on: upon, beyond, accessibility, aceh, in, into, peppers, off,
# Nearest to and: while, or, harboring, mandrakelinux, yan, tucum, husky, but,
# Nearest to the: a, this, its, any, their, another, his, an,
# Nearest to if: when, where, though, because, whether, what, while, however,
# Average loss at step 52000: 3.453870
# Average loss at step 54000: 3.384910
# Average loss at step 56000: 3.165748
# Average loss at step 58000: 3.368521
# Average loss at step 60000: 3.371007
# Nearest to b: atom, function, shatz, wargame, examiner, argonne, number, pair,
# Nearest to not: never, nothing, normalize, entrenched, distal, fairly, still, no,
# Nearest to may: should, might, can, must, will, could, would, cannot,
# Nearest to was: is, were, became, are, remains, becomes, makes, could,
# Nearest to american: america, australian, british, canadian, european, gemara, adopts, margulis,
# Nearest to of: throughout, among, in, recombination, geek, include, bastiat, cite,
# Nearest to so: fins, beaches, infinitesimals, wasted, passport, say, neglect, grounds,
# Nearest to but: however, homophobic, than, yy, though, archipelagoes, outermost, lose,
# Nearest to which: that, what, this, whose, wisc, where, when, equalized,
# Nearest to all: various, many, kitt, these, some, constantinople, those, zheng,
# Nearest to five: six, eight, three, four, zero, seven, astral, cartographic,
# Nearest to seven: six, five, eight, aichi, lutenist, bamberg, arrowhead, four,
# Nearest to on: upon, through, within, beyond, under, staring, in, about,
# Nearest to and: while, dilmun, or, when, acme, ablation, sanity, heterozygote,
# Nearest to the: a, its, this, any, another, an, their, his,
# Nearest to if: when, because, nn, timaeus, denied, normally, uv, biologically,
# Average loss at step 62000: 3.545721
# Average loss at step 64000: 3.403139
# Average loss at step 66000: 3.437376
# Average loss at step 68000: 3.363890
# Average loss at step 70000: 3.365111
# Nearest to b: child, c, myles, marche, truncation, tahitian, herbert, complex,
# Nearest to not: never, still, now, nothing, fairly, also, thujone, no,
# Nearest to may: might, should, could, must, can, will, would, cannot,
# Nearest to was: is, were, became, are, becomes, remains, provides, gives,
# Nearest to american: german, america, musicians, australian, coerce, italian, adopts, americans,
# Nearest to of: following, in, for, between, within, across, behind, zoos,
# Nearest to so: say, handle, believe, announced, how, too, stylized, jagged,
# Nearest to but: however, although, than, though, do, until, while, denizens,
# Nearest to which: that, what, this, where, whose, these, also, secant,
# Nearest to all: many, various, certain, most, some, several, kitt, sulfate,
# Nearest to five: seven, four, six, three, netsplit, eight, alaskans, obscurity,
# Nearest to seven: five, nine, eight, four, six, erica, killers, veritable,
# Nearest to on: upon, beyond, in, staring, within, at, about, through,
# Nearest to and: while, or, via, roslin, etc, palliative, although, including,
# Nearest to the: a, any, another, every, their, this, some, its,
# Nearest to if: where, because, when, that, unless, casanova, therefore, whether,
# Average loss at step 72000: 3.269528
# Average loss at step 74000: 3.255178
# Average loss at step 76000: 3.367222
# Average loss at step 78000: 3.283851
# Average loss at step 80000: 3.136892
# Nearest to b: doubled, d, langle, boltzmann, gylfaginning, pair, hi, faust,
# Nearest to not: never, nothing, bigcup, dreamers, bitstream, mjf, once, often,
# Nearest to may: can, could, must, might, would, should, cannot, will,
# Nearest to was: is, became, becomes, were, remains, are, had, produces,
# Nearest to american: america, scottish, xis, canadian, sparsely, extinguisher, maitland, browsing,
# Nearest to of: following, kampen, among, uomo, include, for, scurvy, whereas,
# Nearest to so: say, proliferate, too, believe, feel, noted, forage, mortimer,
# Nearest to but: although, though, however, than, until, while, because, yet,
# Nearest to which: that, what, where, usually, these, loma, who, mcnamara,
# Nearest to all: various, many, junta, secaucus, archie, those, only, ferenc,
# Nearest to five: three, four, six, seven, zero, two, eight, genscher,
# Nearest to seven: eight, six, nine, five, three, four, spleen, stabbed,
# Nearest to on: upon, through, in, beyond, onto, into, against, bakkers,
# Nearest to and: or, etc, while, tricolor, via, whereas, teaser, including,
# Nearest to the: a, our, his, an, dozens, another, its, europe,
# Nearest to if: though, whether, when, where, unless, because, although, why,
# Average loss at step 82000: 3.261544
# Average loss at step 84000: 3.233649
# Average loss at step 86000: 3.222670
# Average loss at step 88000: 3.157503
# Average loss at step 90000: 3.137421
# Nearest to b: d, faculties, ksc, yung, jen, rossby, leyland, lg,
# Nearest to not: never, nothing, still, battled, macha, tramlink, sometimes, plainly,
# Nearest to may: should, can, will, must, could, might, cannot, would,
# Nearest to was: is, were, became, are, had, does, produces, carries,
# Nearest to american: british, english, agile, scottish, german, canadian, irish, adaptations,
# Nearest to of: including, following, and, among, represents, while, welcomes, disparage,
# Nearest to so: later, believe, too, proliferate, say, heinkel, formalize, intermediary,
# Nearest to but: however, although, though, than, see, or, stabilizes, and,
# Nearest to which: that, where, what, when, who, this, whose, usually,
# Nearest to all: many, certain, always, various, several, some, both, every,
# Nearest to five: three, six, four, seven, eight, two, daw, carelessness,
# Nearest to seven: eight, three, six, four, five, nine, zero, miata,
# Nearest to on: upon, under, in, beyond, onto, kamakura, representing, through,
# Nearest to and: while, or, etc, of, but, however, palliative, bryan,
# Nearest to the: a, its, our, their, his, any, your, an,
# Nearest to if: where, when, though, whether, before, then, indeed, because,
# Average loss at step 92000: 3.271723
# Average loss at step 94000: 3.258810
# Average loss at step 96000: 3.041230
# Average loss at step 98000: 3.228273
# Average loss at step 100000: 3.232143
# Nearest to b: d, f, doubled, smooth, apathetic, constant, metric, ni,
# Nearest to not: never, nothing, still, already, almost, occasionally, inhalation, bitstream,
# Nearest to may: could, can, would, might, should, must, cannot, will,
# Nearest to was: is, became, were, are, remains, had, makes, becomes,
# Nearest to american: british, australian, america, jewish, riverside, libertarians, ladino, sparsely,
# Nearest to of: following, among, represents, while, litters, hog, incompletely, rard,
# Nearest to so: say, too, mean, unreliable, suggest, argue, proliferate, believe,
# Nearest to but: though, although, and, however, than, until, axels, which,
# Nearest to which: that, this, where, whose, these, when, but, sickly,
# Nearest to all: every, various, many, some, several, completely, certain, always,
# Nearest to five: zero, six, three, four, seven, run, two, convert,
# Nearest to seven: six, eight, nine, three, four, five, videogame, zero,
# Nearest to on: upon, beyond, under, onto, around, concerning, in, bakkers,
# Nearest to and: or, but, etc, necker, via, however, rang, teaser,
# Nearest to the: a, any, its, this, their, an, another, our,
# Nearest to if: where, when, though, whether, although, nn, indeed, therefore,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
