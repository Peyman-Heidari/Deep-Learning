# %% [markdown]
# Deep Learning
# =============
#
# Assignment 6
# ------------
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
    f = zipfile.ZipFile(filename)
    for name in f.namelist():
        return tf.compat.as_str(f.read(name))
    f.close()

text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
    if char in string.ascii_lowercase:
        return ord(char) - first_letter + 1
    elif char == ' ':
        return 0
    else:
        print('Unexpected character: %s' % char)
        return 0

def id2char(dictid):
    if dictid > 0:
        return chr(dictid + first_letter - 1)
    else:
        return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
    def __init__(self, text, batch_size, num_unrollings):
        self._text = text
        self._text_size = len(text)
        self._batch_size = batch_size
        self._num_unrollings = num_unrollings
        segment = self._text_size // batch_size
        self._cursor = [ offset * segment for offset in range(batch_size)]
        self._last_batch = self._next_batch()
  
    def _next_batch(self):
        """Generate a single batch from the current cursor position in the data."""
        batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
        for b in range(self._batch_size):
            batch[b, char2id(self._text[self._cursor[b]])] = 1.0
            self._cursor[b] = (self._cursor[b] + 1) % self._text_size
        return batch
  
    def next(self):
        """Generate the next array of batches from the data. The array consists of
        the last batch of the previous array, followed by num_unrollings new ones.
        """
        batches = [self._last_batch]
        for step in range(self._num_unrollings):
            batches.append(self._next_batch())
        self._last_batch = batches[-1]
        return batches

def characters(probabilities):
    """Turn a 1-hot encoding or a probability distribution over the possible
    characters back into its (most likely) character representation."""
    return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
    """Convert a sequence of batches back into their (most likely) string
    representation."""
    s = [''] * batches[0].shape[0]
    for b in batches:
        s = [''.join(x) for x in zip(s, characters(b))]
    return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
    """Log-probability of the true labels in a predicted batch."""
    predictions[predictions < 1e-10] = 1e-10
    return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
    """Sample one element from a distribution assumed to be an array of normalized
      probabilities.
    """
    r = random.uniform(0, 1)
    s = 0
    for i in range(len(distribution)):
        s += distribution[i]
        if s >= r:
            return i
    return len(distribution) - 1

def sample(prediction):
    """Turn a (column) prediction into 1-hot encoded samples."""
    p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
    p[0, sample_distribution(prediction[0])] = 1.0
    return p

def random_distribution():
    """Generate a random column of probabilities."""
    b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
    return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
    # Parameters:
    # Input gate: input, previous output, and bias.
    ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    ib = tf.Variable(tf.zeros([1, num_nodes]))
    # Forget gate: input, previous output, and bias.
    fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    fb = tf.Variable(tf.zeros([1, num_nodes]))
    # Memory cell: input, state and bias.                             
    cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    cb = tf.Variable(tf.zeros([1, num_nodes]))
    # Output gate: input, previous output, and bias.
    ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    ob = tf.Variable(tf.zeros([1, num_nodes]))
    # Variables saving state across unrollings.
    saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    # Classifier weights and biases.
    w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
    b = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Definition of the cell computation.
    def lstm_cell(i, o, state):
        """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
        Note that in this formulation, we omit the various connections between the
        previous state and the gates."""
        input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
        forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
        update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
        state = forget_gate * state + input_gate * tf.tanh(update)
        output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
        return output_gate * tf.tanh(state), state

    # Input data.
    train_data = list()
    for _ in range(num_unrollings + 1):
        train_data.append(tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
    train_inputs = train_data[:num_unrollings]
    train_labels = train_data[1:]  # labels are inputs shifted by one time step.

    # Unrolled LSTM loop.
    outputs = list()
    output = saved_output
    state = saved_state
    for i in train_inputs:
        output, state = lstm_cell(i, output, state)
        outputs.append(output)

    # State saving across unrollings.
    with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
        # Classifier.
        logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
        loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
                            logits, tf.concat(0, train_labels)))

    # Optimizer.
    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(10.0, global_step, 5000, 0.1, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    gradients, v = zip(*optimizer.compute_gradients(loss))
    gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
    optimizer = optimizer.apply_gradients(zip(gradients, v), global_step=global_step)

    # Predictions.
    train_prediction = tf.nn.softmax(logits)
  
    # Sampling and validation eval: batch 1, no unrolling.
    sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
    saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
    saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
    reset_sample_state = tf.group(saved_sample_output.assign(tf.zeros([1, num_nodes])),
                                    saved_sample_state.assign(tf.zeros([1, num_nodes])))
    sample_output, sample_state = lstm_cell(sample_input, saved_sample_output, saved_sample_state)
    with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
        sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    mean_loss = 0
    for step in range(num_steps):
        batches = train_batches.next()
        feed_dict = dict()
        for i in range(num_unrollings + 1):
            feed_dict[train_data[i]] = batches[i]
        _, l, predictions, lr = session.run([optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
        mean_loss += l
        if step % summary_frequency == 0:
            if step > 0:
                mean_loss = mean_loss / summary_frequency
            # The mean loss is an estimate of the loss over the last few batches.
            print('Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
            mean_loss = 0
            labels = np.concatenate(list(batches)[1:])
            print('Minibatch perplexity: %.2f' % float(np.exp(logprob(predictions, labels))))
            if step % (summary_frequency * 10) == 0:
                # Generate some samples.
                print('=' * 80)
                for _ in range(5):
                    feed = sample(random_distribution())
                    sentence = characters(feed)[0]
                    reset_sample_state.run()
                    for _ in range(79):
                        prediction = sample_prediction.eval({sample_input: feed})
                        feed = sample(prediction)
                        sentence += characters(feed)[0]
                    print(sentence)
                print('=' * 80)
            # Measure validation set perplexity.
            reset_sample_state.run()
            valid_logprob = 0
            for _ in range(valid_size):
                b = valid_batches.next()
                predictions = sample_prediction.eval({sample_input: b[0]})
                valid_logprob = valid_logprob + logprob(predictions, b[1])
            print('Validation set perplexity: %.2f' % float(np.exp(valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.295427 learning rate: 10.000000
# Minibatch perplexity: 26.99
# ================================================================================
# kcnmbrwn lrssjxoyegfpzh zoipxtuhlnraf  lw lqtrgdg v   eota tpluhte n hyamso  pek
# vbasrd t tlqlsayfdp rqr nwzsd nkpucwfjcwfrw niavs gtwc binmgu srtkevtaehisoei ii
# ljjle bhtctqjbu ntunbxap fmem ch pwt hiive qdekezetyghcfrjmttcvsovvkizrsdhsc dre
# m drqgbkyu qt zqkevxihoeuontqwvqfpiabrp frb gat aoffdpisemi rza eisernwcsalzoar
# bot  ojcmz titcuhvascl ljyi vfezimgbecthebeifhda  yebsfoqskgm zj nuwz r ht s  lf
# ================================================================================
# Validation set perplexity: 20.24
# Average loss at step 100: 2.585525 learning rate: 10.000000
# Minibatch perplexity: 10.94
# Validation set perplexity: 10.46
# Average loss at step 200: 2.239480 learning rate: 10.000000
# Minibatch perplexity: 8.67
# Validation set perplexity: 8.52
# Average loss at step 300: 2.093047 learning rate: 10.000000
# Minibatch perplexity: 7.29
# Validation set perplexity: 7.86
# Average loss at step 400: 1.994532 learning rate: 10.000000
# Minibatch perplexity: 7.40
# Validation set perplexity: 7.45
# Average loss at step 500: 1.930875 learning rate: 10.000000
# Minibatch perplexity: 6.25
# Validation set perplexity: 6.86
# Average loss at step 600: 1.905909 learning rate: 10.000000
# Minibatch perplexity: 6.36
# Validation set perplexity: 6.75
# Average loss at step 700: 1.858149 learning rate: 10.000000
# Minibatch perplexity: 6.50
# Validation set perplexity: 6.44
# Average loss at step 800: 1.820211 learning rate: 10.000000
# Minibatch perplexity: 5.90
# Validation set perplexity: 6.18
# Average loss at step 900: 1.826384 learning rate: 10.000000
# Minibatch perplexity: 6.88
# Validation set perplexity: 6.15
# Average loss at step 1000: 1.825170 learning rate: 10.000000
# Minibatch perplexity: 5.66
# ================================================================================
# meteral belbial b heudery of peiruse one zero is slefsc while to are his of the
# buen of proach pefreates the frommate yoric biph departallysed as time in rook s
# d prearchericics showht be wollw beincmones in owert is feater reternil als unde
# jentry hild the peart kamin k as ourals breed ady used of so souther stond be fi
# ine noter it eirelower of logerch enflowkh exwring insted five of been over his
# ================================================================================
# Validation set perplexity: 5.91
# Average loss at step 1100: 1.776888 learning rate: 10.000000
# Minibatch perplexity: 5.47
# Validation set perplexity: 5.77
# Average loss at step 1200: 1.752307 learning rate: 10.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 5.60
# Average loss at step 1300: 1.732315 learning rate: 10.000000
# Minibatch perplexity: 5.70
# Validation set perplexity: 5.56
# Average loss at step 1400: 1.746412 learning rate: 10.000000
# Minibatch perplexity: 5.84
# Validation set perplexity: 5.48
# Average loss at step 1500: 1.737840 learning rate: 10.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 5.35
# Average loss at step 1600: 1.747376 learning rate: 10.000000
# Minibatch perplexity: 5.49
# Validation set perplexity: 5.36
# Average loss at step 1700: 1.712210 learning rate: 10.000000
# Minibatch perplexity: 5.72
# Validation set perplexity: 5.31
# Average loss at step 1800: 1.677845 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 5.20
# Average loss at step 1900: 1.647277 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 5.07
# Average loss at step 2000: 1.700449 learning rate: 10.000000
# Minibatch perplexity: 5.70
# ================================================================================
# k storchs oftinits soing betbongs to banktos effented on naturee bystandly intil
# y ascalqural nuttied ofsa states tradationing di the mode carrents ton four mp s
# ng home the long boging obsering intiarcover bankpha arkents attembing as lix as
# war are county one nine nine six six eight sidens six four four two zero lingunt
# anghing that on oriests ie of the tno as the lattical traphismonity benn s of he
# ================================================================================
# Validation set perplexity: 5.17
# Average loss at step 2100: 1.687891 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 4.82
# Average loss at step 2200: 1.683435 learning rate: 10.000000
# Minibatch perplexity: 6.43
# Validation set perplexity: 4.95
# Average loss at step 2300: 1.645971 learning rate: 10.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 4.74
# Average loss at step 2400: 1.663192 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 4.65
# Average loss at step 2500: 1.684467 learning rate: 10.000000
# Minibatch perplexity: 5.45
# Validation set perplexity: 4.58
# Average loss at step 2600: 1.656241 learning rate: 10.000000
# Minibatch perplexity: 5.78
# Validation set perplexity: 4.52
# Average loss at step 2700: 1.660217 learning rate: 10.000000
# Minibatch perplexity: 4.52
# Validation set perplexity: 4.65
# Average loss at step 2800: 1.657452 learning rate: 10.000000
# Minibatch perplexity: 5.82
# Validation set perplexity: 4.54
# Average loss at step 2900: 1.655020 learning rate: 10.000000
# Minibatch perplexity: 5.65
# Validation set perplexity: 4.62
# Average loss at step 3000: 1.656553 learning rate: 10.000000
# Minibatch perplexity: 5.20
# ================================================================================
#  apartics a passided fertoring the becaut balded nost one lices distar in lyndin
# uswadi avarition or besaugh weerd wilchknewine with at teytripn of appaning ppyp
# malved a six place l singlemandin often ratmenta onesing one one nine seven nine
# om would colleges the first porched mublismanns of hanscold destribe common comm
# ol with aftermemin joingle in would in two deconsitios of larding pass them rete
# ================================================================================
# Validation set perplexity: 4.62
# Average loss at step 3100: 1.635291 learning rate: 10.000000
# Minibatch perplexity: 5.77
# Validation set perplexity: 4.54
# Average loss at step 3200: 1.649428 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 4.52
# Average loss at step 3300: 1.642200 learning rate: 10.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 4.43
# Average loss at step 3400: 1.670882 learning rate: 10.000000
# Minibatch perplexity: 5.61
# Validation set perplexity: 4.45
# Average loss at step 3500: 1.661488 learning rate: 10.000000
# Minibatch perplexity: 5.52
# Validation set perplexity: 4.48
# Average loss at step 3600: 1.676081 learning rate: 10.000000
# Minibatch perplexity: 4.56
# Validation set perplexity: 4.44
# Average loss at step 3700: 1.650259 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 4.40
# Average loss at step 3800: 1.644406 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 4.53
# Average loss at step 3900: 1.640043 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.50
# Average loss at step 4000: 1.656213 learning rate: 10.000000
# Minibatch perplexity: 4.72
# ================================================================================
# legay trounted dy magrox infiic gromen age with the nine two the died for the an
# repped be week the fieahsticle his risings the same peni curt formed bolleed a u
# ize photz one eix allers two zero four eight six one stiths elected vaences fur
# sics and and the strictre extension dae vanyportate intersibation main the remai
# gienena directed by chinsa rove to elecisher shysent neacies syars unites hissor
# ================================================================================
# Validation set perplexity: 4.62
# Average loss at step 4100: 1.635703 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 4.61
# Average loss at step 4200: 1.639560 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.39
# Average loss at step 4300: 1.617560 learning rate: 10.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 4.37
# Average loss at step 4400: 1.614064 learning rate: 10.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 4.30
# Average loss at step 4500: 1.619026 learning rate: 10.000000
# Minibatch perplexity: 5.38
# Validation set perplexity: 4.44
# Average loss at step 4600: 1.619993 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 4.54
# Average loss at step 4700: 1.633377 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.36
# Average loss at step 4800: 1.633071 learning rate: 10.000000
# Minibatch perplexity: 4.47
# Validation set perplexity: 4.33
# Average loss at step 4900: 1.637117 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 4.51
# Average loss at step 5000: 1.612205 learning rate: 1.000000
# Minibatch perplexity: 4.52
# ================================================================================
# ine the firner he as a partly crowse in their bursel state to wikin a told in hi
# x not r the giving realik by used intensives kinitb of then sparqus that the par
# scoech is the efficient temage resugrhiture wich pala and sometins combont be th
# juever of gengante mase molism produted my and mats on the mith a thomple time h
# plaby sankimane and refent deaint to many him pieces catbaver off in the linka t
# ================================================================================
# Validation set perplexity: 4.51
# Average loss at step 5100: 1.607678 learning rate: 1.000000
# Minibatch perplexity: 4.84
# Validation set perplexity: 4.31
# Average loss at step 5200: 1.595363 learning rate: 1.000000
# Minibatch perplexity: 4.64
# Validation set perplexity: 4.25
# Average loss at step 5300: 1.579473 learning rate: 1.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 4.26
# Average loss at step 5400: 1.582459 learning rate: 1.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 4.23
# Average loss at step 5500: 1.568233 learning rate: 1.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 4.21
# Average loss at step 5600: 1.584385 learning rate: 1.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 4.20
# Average loss at step 5700: 1.570592 learning rate: 1.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 4.21
# Average loss at step 5800: 1.587556 learning rate: 1.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 4.21
# Average loss at step 5900: 1.576692 learning rate: 1.000000
# Minibatch perplexity: 4.99
# Validation set perplexity: 4.19
# Average loss at step 6000: 1.550409 learning rate: 1.000000
# Minibatch perplexity: 5.03
# ================================================================================
# eged be dirixumal is over the lister of including more in recently won auto keli
# nee alpattron utforivation and well bievex to som bow ii mile saupire the caster
# k desall the gensection the looking with one one seven to five one four two fay
# g was codjume was the coeps lecal edt iccates armic gaonimance may they cathopin
# ing in an and late s abprivization and its soutony arms hamole uaring sceles to
# ================================================================================
# Validation set perplexity: 4.20
# Average loss at step 6100: 1.571064 learning rate: 1.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 4.17
# Average loss at step 6200: 1.535992 learning rate: 1.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.18
# Average loss at step 6300: 1.551701 learning rate: 1.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.16
# Average loss at step 6400: 1.549117 learning rate: 1.000000
# Minibatch perplexity: 4.59
# Validation set perplexity: 4.16
# Average loss at step 6500: 1.558482 learning rate: 1.000000
# Minibatch perplexity: 4.54
# Validation set perplexity: 4.16
# Average loss at step 6600: 1.600277 learning rate: 1.000000
# Minibatch perplexity: 4.82
# Validation set perplexity: 4.15
# Average loss at step 6700: 1.587482 learning rate: 1.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 4.18
# Average loss at step 6800: 1.608737 learning rate: 1.000000
# Minibatch perplexity: 4.76
# Validation set perplexity: 4.17
# Average loss at step 6900: 1.587657 learning rate: 1.000000
# Minibatch perplexity: 4.64
# Validation set perplexity: 4.21
# Average loss at step 7000: 1.582930 learning rate: 1.000000
# Minibatch perplexity: 5.10
# ================================================================================
# s a instraction such as the closestly an a for booke system the useans was as th
# laur denory they buils sour sorus make and however is a digued by folld out itil
# vest warri torgy infeding encoud and pland is a monkinists creativity and week o
# pitactor fledligh is of p pil hege prodic two not he to pates one four nine cose
# x action that a generated young particud charge giving of the opensist human edu
# ================================================================================
# Validation set perplexity: 4.20

# %% [markdown]
# ---
# Problem 1
# ---------
#
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.
#
# ---

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
    # Parameters:
    x_multiplier = tf.Variable(tf.truncated_normal([4*vocabulary_size, num_nodes], -0.1, 0.1))
    o_mulltiplier = tf.Variable(tf.truncated_normal([4*num_nodes, num_nodes], -0.1, 0.1))
    biases = tf.Variable(tf.zeros([1, num_nodes*4]))
    ix, fx, cx, ox = tf.split(0, 4, x_multiplier)
    im, fm, cm, om = tf.split(0, 4, o_mulltiplier)
    ib, fb, cb, ob = tf.split(1, 4, biases)
    # Input gate: input, previous output, and bias.
    #ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    #im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    #ib = tf.Variable(tf.zeros([1, num_nodes]))
    # Forget gate: input, previous output, and bias.
    #fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    #fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    #fb = tf.Variable(tf.zeros([1, num_nodes]))
    # Memory cell: input, state and bias.                             
    #cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    #cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    #cb = tf.Variable(tf.zeros([1, num_nodes]))
    # Output gate: input, previous output, and bias.
    #ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    #om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    
    
    # Variables saving state across unrollings.
    saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    # Classifier weights and biases.
    w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
    b = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Definition of the cell computation.
    def lstm_cell(i, o, state):
        """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
        Note that in this formulation, we omit the various connections between the
        previous state and the gates."""
        input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
        forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
        update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
        state = forget_gate * state + input_gate * tf.tanh(update)
        output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
        return output_gate * tf.tanh(state), state

    # Input data.
    train_data = list()
    for _ in range(num_unrollings + 1):
        train_data.append(tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
    train_inputs = train_data[:num_unrollings]
    train_labels = train_data[1:]  # labels are inputs shifted by one time step.

    # Unrolled LSTM loop.
    outputs = list()
    output = saved_output
    state = saved_state
    for i in train_inputs:
        output, state = lstm_cell(i, output, state)
        outputs.append(output)

    # State saving across unrollings.
    with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
        # Classifier.
        logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
        loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
                            logits, tf.concat(0, train_labels)))

    # Optimizer.
    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(10.0, global_step, 5000, 0.1, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    gradients, v = zip(*optimizer.compute_gradients(loss))
    gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
    optimizer = optimizer.apply_gradients(zip(gradients, v), global_step=global_step)

    # Predictions.
    train_prediction = tf.nn.softmax(logits)
  
    # Sampling and validation eval: batch 1, no unrolling.
    sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
    saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
    saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
    reset_sample_state = tf.group(saved_sample_output.assign(tf.zeros([1, num_nodes])),
                                    saved_sample_state.assign(tf.zeros([1, num_nodes])))
    sample_output, sample_state = lstm_cell(sample_input, saved_sample_output, saved_sample_state)
    with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
        sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    mean_loss = 0
    for step in range(num_steps):
        batches = train_batches.next()
        feed_dict = dict()
        for i in range(num_unrollings + 1):
            feed_dict[train_data[i]] = batches[i]
        _, l, predictions, lr = session.run([optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
        mean_loss += l
        if step % summary_frequency == 0:
            if step > 0:
                mean_loss = mean_loss / summary_frequency
            # The mean loss is an estimate of the loss over the last few batches.
            print('Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
            mean_loss = 0
            labels = np.concatenate(list(batches)[1:])
            print('Minibatch perplexity: %.2f' % float(np.exp(logprob(predictions, labels))))
            if step % (summary_frequency * 10) == 0:
                # Generate some samples.
                print('=' * 80)
                for _ in range(5):
                    feed = sample(random_distribution())
                    sentence = characters(feed)[0]
                    reset_sample_state.run()
                    for _ in range(79):
                        prediction = sample_prediction.eval({sample_input: feed})
                        feed = sample(prediction)
                        sentence += characters(feed)[0]
                    print(sentence)
                print('=' * 80)
            # Measure validation set perplexity.
            reset_sample_state.run()
            valid_logprob = 0
            for _ in range(valid_size):
                b = valid_batches.next()
                predictions = sample_prediction.eval({sample_input: b[0]})
                valid_logprob = valid_logprob + logprob(predictions, b[1])
            print('Validation set perplexity: %.2f' % float(np.exp(valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.297345 learning rate: 10.000000
# Minibatch perplexity: 27.04
# ================================================================================
# ja edu u  bt eejtce dfdeywg  fhczh bsdhw ie  u ihita jycuznednlcidiexjebxd v  ca
# eesi rpeirnnh qtz rh  bzvrfomtuoaquijlbh  oahh slevhsfsrbk rhtalr af  oi p cifjj
# ayd kmttuskwsyyhdh slbiq m fqunaine d  hc pxh ipo n knbyfibbs ps eyaeimdiof t dh
# ja  s uxatypv  xaed icovizvqjbnaujeigmswr a dwuag cyhijlue aej e iuexdipfhdo lz
# zlldd aemii aag s ic uhxqcuheytjcymy tzfs sh  nax mw leesxozjci aq omi u o mot
# ================================================================================
# Validation set perplexity: 19.94
# Average loss at step 100: 2.584383 learning rate: 10.000000
# Minibatch perplexity: 10.74
# Validation set perplexity: 10.53
# Average loss at step 200: 2.246363 learning rate: 10.000000
# Minibatch perplexity: 8.45
# Validation set perplexity: 8.89
# Average loss at step 300: 2.090233 learning rate: 10.000000
# Minibatch perplexity: 6.53
# Validation set perplexity: 8.07
# Average loss at step 400: 2.040732 learning rate: 10.000000
# Minibatch perplexity: 7.78
# Validation set perplexity: 7.83
# Average loss at step 500: 1.979878 learning rate: 10.000000
# Minibatch perplexity: 6.55
# Validation set perplexity: 7.01
# Average loss at step 600: 1.898394 learning rate: 10.000000
# Minibatch perplexity: 6.54
# Validation set perplexity: 6.82
# Average loss at step 700: 1.869024 learning rate: 10.000000
# Minibatch perplexity: 6.74
# Validation set perplexity: 6.54
# Average loss at step 800: 1.867380 learning rate: 10.000000
# Minibatch perplexity: 7.05
# Validation set perplexity: 6.57
# Average loss at step 900: 1.843106 learning rate: 10.000000
# Minibatch perplexity: 6.14
# Validation set perplexity: 6.33
# Average loss at step 1000: 1.846335 learning rate: 10.000000
# Minibatch perplexity: 6.47
# ================================================================================
# fer f tely four the s scume relt bat agriqus recosings devasuriesh vampidan bata
# d of a nona died is sirts hav the conjule one nine siggs one eight nine eight ni
# k one eight fel one feur one eague one nine figsh segural asscourt with fictive
# x schenele strikut hinosive this has in bely by bolic the two kninge this in one
# phery jober two rigun one five five one nine seven feveren one enieine one eight
# ================================================================================
# Validation set perplexity: 6.24
# Average loss at step 1100: 1.805352 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 6.27
# Average loss at step 1200: 1.771236 learning rate: 10.000000
# Minibatch perplexity: 6.34
# Validation set perplexity: 6.13
# Average loss at step 1300: 1.763244 learning rate: 10.000000
# Minibatch perplexity: 5.92
# Validation set perplexity: 5.86
# Average loss at step 1400: 1.763023 learning rate: 10.000000
# Minibatch perplexity: 6.16
# Validation set perplexity: 5.73
# Average loss at step 1500: 1.748073 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 5.45
# Average loss at step 1600: 1.732100 learning rate: 10.000000
# Minibatch perplexity: 5.52
# Validation set perplexity: 5.61
# Average loss at step 1700: 1.715990 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 5.44
# Average loss at step 1800: 1.694392 learning rate: 10.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 5.17
# Average loss at step 1900: 1.695050 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 5.33
# Average loss at step 2000: 1.683004 learning rate: 10.000000
# Minibatch perplexity: 4.87
# ================================================================================
# arth kaptive and seven is mikin a son amenswed entanm bycleo poemme as folf exte
# jus of the iscradication inde two zero zero zero two zero zero nine six seven si
# pests to diseams implems fift sictions of thes bose ebically perce two one zero
# gal burching the work of born seven one two fourle the lom will netabonation and
# usbl his sectediul fein the noted excelfs the codes althoogs retoll demaked elle
# ================================================================================
# Validation set perplexity: 5.31
# Average loss at step 2100: 1.683804 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 5.35
# Average loss at step 2200: 1.710077 learning rate: 10.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 5.25
# Average loss at step 2300: 1.707967 learning rate: 10.000000
# Minibatch perplexity: 6.42
# Validation set perplexity: 5.30
# Average loss at step 2400: 1.687386 learning rate: 10.000000
# Minibatch perplexity: 5.95
# Validation set perplexity: 5.35
# Average loss at step 2500: 1.691501 learning rate: 10.000000
# Minibatch perplexity: 5.92
# Validation set perplexity: 5.27
# Average loss at step 2600: 1.673244 learning rate: 10.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 5.14
# Average loss at step 2700: 1.687478 learning rate: 10.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 5.21
# Average loss at step 2800: 1.683818 learning rate: 10.000000
# Minibatch perplexity: 5.52
# Validation set perplexity: 5.32
# Average loss at step 2900: 1.676545 learning rate: 10.000000
# Minibatch perplexity: 6.57
# Validation set perplexity: 5.22
# Average loss at step 3000: 1.683962 learning rate: 10.000000
# Minibatch perplexity: 4.84
# ================================================================================
# hatide and jrailg under based in part and to centionifl movistia intern used thr
# bas a lixr commer of word and estamie atorian treated and two km unstri wrors st
# y was the mainel cul mern soll european six wamated and h commony nenen five par
# war formory pats the tegricita remorp awain the souties and aban dive maus clave
# raper by to the sirce russ puil write to readed very is refererkin chable are is
# ================================================================================
# Validation set perplexity: 5.20
# Average loss at step 3100: 1.653725 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 5.06
# Average loss at step 3200: 1.642429 learning rate: 10.000000
# Minibatch perplexity: 5.50
# Validation set perplexity: 4.98
# Average loss at step 3300: 1.648027 learning rate: 10.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 4.91
# Average loss at step 3400: 1.635273 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 5.03
# Average loss at step 3500: 1.677344 learning rate: 10.000000
# Minibatch perplexity: 6.09
# Validation set perplexity: 5.03
# Average loss at step 3600: 1.659570 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 4.84
# Average loss at step 3700: 1.650658 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.85
# Average loss at step 3800: 1.658597 learning rate: 10.000000
# Minibatch perplexity: 5.82
# Validation set perplexity: 4.91
# Average loss at step 3900: 1.653422 learning rate: 10.000000
# Minibatch perplexity: 4.33
# Validation set perplexity: 4.86
# Average loss at step 4000: 1.645470 learning rate: 10.000000
# Minibatch perplexity: 5.45
# ================================================================================
# hist of three kaberdy syitessuris and egulya existsmoding in the nectockes be jo
# hal spile west dzeestral of a no gale capuction tere mansubish over the envor be
# uns the peact hamb these trackanus preconations of the evance were one ciab one
# cust neadure year avernacte klove majands and grax the hatweller godphisthyi ban
# quaction units examplasz contise ka ghinsic and niever procnian feed fasg first
# ================================================================================
# Validation set perplexity: 4.85
# Average loss at step 4100: 1.624626 learning rate: 10.000000
# Minibatch perplexity: 4.83
# Validation set perplexity: 4.74
# Average loss at step 4200: 1.615917 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.85
# Average loss at step 4300: 1.621745 learning rate: 10.000000
# Minibatch perplexity: 5.61
# Validation set perplexity: 4.87
# Average loss at step 4400: 1.611908 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 4.85
# Average loss at step 4500: 1.645306 learning rate: 10.000000
# Minibatch perplexity: 5.28
# Validation set perplexity: 4.95
# Average loss at step 4600: 1.628106 learning rate: 10.000000
# Minibatch perplexity: 5.44
# Validation set perplexity: 4.85
# Average loss at step 4700: 1.627586 learning rate: 10.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 4.87
# Average loss at step 4800: 1.610352 learning rate: 10.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 4.83
# Average loss at step 4900: 1.622745 learning rate: 10.000000
# Minibatch perplexity: 5.20
# Validation set perplexity: 4.74
# Average loss at step 5000: 1.617858 learning rate: 1.000000
# Minibatch perplexity: 4.93
# ================================================================================
# ward supperists cole tenv meakurys syplearth in underphy  servalia doral on the
# able the powernic b one nine nine five jown recent word bestuef hohers the yrase
# han to there bind mare heap the trist commensed to one nine seven eight consicro
# fibe the balleon octokems toures buigrry bablelbow eloplli johns catee accoumati
# niogres area braigract thing see with doembiny at ognaling and the hereas in one
# ================================================================================
# Validation set perplexity: 4.75
# Average loss at step 5100: 1.594344 learning rate: 1.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.65
# Average loss at step 5200: 1.595771 learning rate: 1.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 4.65
# Average loss at step 5300: 1.595304 learning rate: 1.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.63
# Average loss at step 5400: 1.592658 learning rate: 1.000000
# Minibatch perplexity: 4.82
# Validation set perplexity: 4.63
# Average loss at step 5500: 1.592921 learning rate: 1.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.59
# Average loss at step 5600: 1.561352 learning rate: 1.000000
# Minibatch perplexity: 4.30
# Validation set perplexity: 4.57
# Average loss at step 5700: 1.580488 learning rate: 1.000000
# Minibatch perplexity: 4.73
# Validation set perplexity: 4.52
# Average loss at step 5800: 1.605751 learning rate: 1.000000
# Minibatch perplexity: 4.54
# Validation set perplexity: 4.54
# Average loss at step 5900: 1.586966 learning rate: 1.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 4.54
# Average loss at step 6000: 1.585703 learning rate: 1.000000
# Minibatch perplexity: 4.85
# ================================================================================
# low rall this presultin a spame feature factorn examelistivial and the gio funnu
# lot by aul one nine nine the consome cates it a commonsed a literfire and mergam
# use one nine five five zero zero viroc and the soin larder with the mylement lan
# zern the for sub mathed a south hangior to gougent the umprackia jochis tarbicas
# d was turn splay of a edpo barmeder to of versionor that johna he lists enjerenc
# ================================================================================
# Validation set perplexity: 4.51
# Average loss at step 6100: 1.580002 learning rate: 1.000000
# Minibatch perplexity: 4.33
# Validation set perplexity: 4.54
# Average loss at step 6200: 1.591530 learning rate: 1.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 4.56
# Average loss at step 6300: 1.583413 learning rate: 1.000000
# Minibatch perplexity: 5.46
# Validation set perplexity: 4.59
# Average loss at step 6400: 1.574552 learning rate: 1.000000
# Minibatch perplexity: 4.15
# Validation set perplexity: 4.59
# Average loss at step 6500: 1.557662 learning rate: 1.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 4.57
# Average loss at step 6600: 1.602276 learning rate: 1.000000
# Minibatch perplexity: 5.75
# Validation set perplexity: 4.56
# Average loss at step 6700: 1.573718 learning rate: 1.000000
# Minibatch perplexity: 5.43
# Validation set perplexity: 4.56
# Average loss at step 6800: 1.576786 learning rate: 1.000000
# Minibatch perplexity: 4.83
# Validation set perplexity: 4.58
# Average loss at step 6900: 1.574053 learning rate: 1.000000
# Minibatch perplexity: 4.59
# Validation set perplexity: 4.55
# Average loss at step 7000: 1.593967 learning rate: 1.000000
# Minibatch perplexity: 5.05
# ================================================================================
# qus any wilk one one few cheak positions he subm accoporal probeded for the refe
# zer hitfine for russius of the bacely roch bewame number knams pussics as staiti
# zered as celcen deersed are consideratic a mychu with the basinose and somes inv
# undin supplem where grage mannation standar lingon claiming of charge who number
# fing time servell tides by eachs in dososm leeds with dozate the bharse it ablel
# ================================================================================
# Validation set perplexity: 4.52

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).
#
# ---

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
#
# ---
